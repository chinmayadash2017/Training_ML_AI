# %%
import pandas as pd
import numpy as np
import json
from dtree_utils import categorical_2_binary, intermediate_node_num_mistakes, best_splitting_feature
from dtree_utils import create_leaf, decision_tree_create,classify, evaluate_classification_error, new_evaluate_classification_error

# %%
loans = pd.read_csv("lending-club-data.csv")
# Out:
# C:\Users\chinm\AppData\Local\conda\conda\envs\tensorflow\lib\site-packages\IPython\core\interactiveshell.py:2698: DtypeWarning: Columns (19,47) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
loans["safe_loans"] = loans["bad_loans"].apply(lambda x : 1 if x == 0 else -1)
loans.drop("bad_loans", axis = 1)
print("Number of columns: %d" %(len(loans.columns)))
# Out:
# Number of columns: 69

# %%
features = ['grade',              # grade of the loan
            'term',               # the term of the loan
            'home_ownership',     # home_ownership status: own, mortgage or rent
            'emp_length',         # number of years of employment
           ]
target = ['safe_loans']

# %%
loans = loans[features + target]
print("Number of columns: %d" %(len(loans.columns)))
# Out:
# Number of columns: 5

# %%
loans = categorical_2_binary(loans, cat_feature = features, flag = True)

# %%
with open("module-6-assignment-train-idx.json","r") as data:
    train_idx = json.load(data)
with open("module-6-assignment-validation-idx.json","r") as data:
    validation_idx = json.load(data)

# %%
train_data = loans.iloc[train_idx]
validation_data = loans.iloc[validation_idx]
print("Shape of training data: %d" %(train_data.shape[0]))
print("Shape of validation data: %d" %(validation_data.shape[0]))
# Out:
# Shape of training data: 37224
# Shape of validation data: 9284

# %%
train_data.columns
# Out:
# Index(['safe_loans', 'grade_A', 'grade_B', 'grade_C', 'grade_D', 'grade_E',
#        'grade_F', 'grade_G', 'term_ 36 months', 'term_ 60 months',
#        'home_ownership_MORTGAGE', 'home_ownership_OTHER', 'home_ownership_OWN',
#        'home_ownership_RENT', 'emp_length_1 year', 'emp_length_10+ years',
#        'emp_length_2 years', 'emp_length_3 years', 'emp_length_4 years',
#        'emp_length_5 years', 'emp_length_6 years', 'emp_length_7 years',
#        'emp_length_8 years', 'emp_length_9 years', 'emp_length_< 1 year'],
#       dtype='object')

# %% [markdown]
# #### Quiz question: Given an intermediate node with 6 safe loans and 3 risky loans, if the min_node_size parameter is 10, what should the tree learning algorithm do next?

# %%
# tree will create a leaf there, with safe loans prediction

# %% [markdown]
# #### Quiz question: Assume an intermediate node has 6 safe loans and 3 risky loans.
# #### For each of 4 possible features to split on, the error reduction is 0.0, 0.05, 0.1, and 0.14,
# #### respectively. If the minimum gain in error reduction parameter is set to 0.2,
# #### what should the tree learning algorithm do next?

# %%
# ans: will craete leaf,with safe loans prediction

# %%
#### Build a tree!
### 13. Now that your code is working, train a tree model on the train_data with

# %%
x = train_data.drop('safe_loans', axis = 1)
features_new = [col for col in x.columns]

# %%
my_decision_tree_new = decision_tree_create(train_data, features_new, "safe_loans", current_depth = 0, max_depth = 6, min_node_size=100, min_error_reduction=0.0)
# Out:
# --------------------------------------------------------------------
# Subtree, depth = 0 (37224 data points).
# Split on feature term_ 36 months. (9223, 28001)
# --------------------------------------------------------------------
# Subtree, depth = 1 (9223 data points).
# Split on feature grade_A. (9122, 101)
# --------------------------------------------------------------------
# Subtree, depth = 2 (9122 data points).
# Early stopping condition 3 reached. Minimum error reduction.
# --------------------------------------------------------------------
# Subtree, depth = 2 (101 data points).
# Split on feature emp_length_< 1 year. (90, 11)
# --------------------------------------------------------------------
# Subtree, depth = 3 (90 data points).
# Early stopping condition 2 reached. Reached minimum node size.
# --------------------------------------------------------------------
# Subtree, depth = 3 (11 data points).
# Early stopping condition 2 reached. Reached minimum node size.
# ...

# %%
my_decision_tree_old = decision_tree_create(train_data, features_new, 'safe_loans', max_depth = 6, min_node_size = 0, min_error_reduction=-1)
print(x)
# Out:
# --------------------------------------------------------------------
# Subtree, depth = 0 (37224 data points).
# Split on feature term_ 36 months. (9223, 28001)
# --------------------------------------------------------------------
# Subtree, depth = 1 (9223 data points).
# Split on feature grade_A. (9122, 101)
# --------------------------------------------------------------------
# Subtree, depth = 2 (9122 data points).
# Split on feature grade_B. (8074, 1048)
# --------------------------------------------------------------------
# Subtree, depth = 3 (8074 data points).
# Split on feature grade_C. (5884, 2190)
# --------------------------------------------------------------------
# Subtree, depth = 4 (5884 data points).
# Split on feature grade_D. (3826, 2058)
# --------------------------------------------------------------------
# Subtree, depth = 5 (3826 data points).
# Split on feature grade_E. (1693, 2133)
# --------------------------------------------------------------------
# ...

# %%
for a in validation_data[0:1].to_dict(orient = 'records'):
    print (a)
# Out:
# {'emp_length_3 years': 0, 'emp_length_9 years': 0, 'emp_length_10+ years': 0, 'safe_loans': -1, 'term_ 60 months': 1, 'grade_C': 0, 'term_ 36 months': 0, 'emp_length_6 years': 0, 'emp_length_5 years': 0, 'home_ownership_RENT': 1, 'grade_G': 0, 'emp_length_1 year': 0, 'home_ownership_OTHER': 0, 'grade_E': 0, 'emp_length_2 years': 1, 'home_ownership_OWN': 0, 'emp_length_8 years': 0, 'grade_D': 1, 'grade_B': 0, 'grade_A': 0, 'home_ownership_MORTGAGE': 0, 'emp_length_4 years': 0, 'emp_length_< 1 year': 0, 'grade_F': 0, 'emp_length_7 years': 0}

# %%
a["safe_loans"]
# Out:
# -1

# %%
classify(my_decision_tree_new, a)
# Out:
# -1

# %%
classify(my_decision_tree_new, a, annotate = True)
# Out:
# Split on term_ 36 months = 0
# Split on grade_A = 0
# At leaf, predicting -1
# -1

# %%
classify(my_decision_tree_old, a, annotate = True)
# Out:
# Split on term_ 36 months = 0
# Split on grade_A = 0
# Split on grade_B = 0
# Split on grade_C = 0
# Split on grade_D = 1
# Split on grade_E = 0
# At leaf, predicting -1
# -1

# %% [markdown]
# #### Quiz question: For my_decision_tree_new trained with max_depth = 6, min_node_size = 100, min_error_reduction=0.0, is the prediction path for validation_set[0] shorter, longer, or the same as for my_decision_tree_old that ignored the early stopping conditions 2 and 3?
#
# Ans: Shorter
#
# #### Quiz question: For my_decision_tree_new trained with max_depth = 6, min_node_size = 100, min_error_reduction=0.0, is the prediction path for any point always shorter, always longer, always the same, shorter or the same, or longer or the same as for my_decision_tree_old that ignored the early stopping conditions 2 and 3?
#
# Ans : always shorter
#
# #### Quiz question: For a tree trained on any dataset using max_depth = 6, min_node_size = 100, min_error_reduction=0.0, what is the maximum number of splits encountered while making a single prediction?
#
# Ans: 2

# %%
# Evaluating the model

# %%
print(len(my_decision_tree_old))
# Out:
# 5

# %%
new_evaluate_classification_error(my_decision_tree_new, validation_data)
# Out:
# D:\ML_Python\Coursera\Machine Learning_WU\Assignments\wk3_decision_tree\dtree_utils.py:264: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   data['prediction'] = [classify(tree,a) for a in data.to_dict(orient = 'records')]
# 0.3777

# %%
new_evaluate_classification_error(my_decision_tree_old, validation_data)
# Out:
# D:\ML_Python\Coursera\Machine Learning_WU\Assignments\wk3_decision_tree\dtree_utils.py:264: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   data['prediction'] = [classify(tree,a) for a in data.to_dict(orient = 'records')]
# 0.3777

# %% [markdown]
# #### Quiz question: Is the validation error of the new decision tree (using early stopping conditions 2 and 3) lower than, higher than, or the same as that of the old decision tree from the previous assignment?
# ans : Same

# %% [markdown]
# ##### Exploring the effect of max_depth
# We will compare three models trained with different values of the stopping criterion. Again, intentionally picked models at the extreme ends (too small, just right, and just right).
#
# We will compare three models trained with different values of the stopping criterion. We intentionally picked models at the extreme ends (too small, just right, and too large).
#
# Train three models with these parameters:
#
# model_1: max_depth = 2 (too small) model_2: max_depth = 6 (just right) model_3: max_depth = 14 (may be too large) For each of these three, set min_node_size = 0 and min_error_reduction = -1. Make sure to call the models model_1, model_2, and model_3.
#
# Note: Each tree can take up to a few minutes to train. In particular, model_3 will probably take the longest to train.

# %%
model_1 = decision_tree_create(train_data, features_new, "safe_loans", current_depth = 0, max_depth = 2, min_node_size=0, min_error_reduction=-1)
# Out:
# --------------------------------------------------------------------
# Subtree, depth = 0 (37224 data points).
# Split on feature term_ 36 months. (9223, 28001)
# --------------------------------------------------------------------
# Subtree, depth = 1 (9223 data points).
# Split on feature grade_A. (9122, 101)
# --------------------------------------------------------------------
# Subtree, depth = 2 (9122 data points).
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 2 (101 data points).
# Early stopping condition 1 reached. Reached maximum depth.
# --------------------------------------------------------------------
# Subtree, depth = 1 (28001 data points).
# Split on feature grade_D. (23300, 4701)
# --------------------------------------------------------------------
# Subtree, depth = 2 (23300 data points).
# Early stopping condition 1 reached. Reached maximum depth.
# ...

# %%
model_2 = decision_tree_create(train_data, features_new, "safe_loans", current_depth = 0, max_depth = 6, min_node_size=0, min_error_reduction=-1)
# Out:
# --------------------------------------------------------------------
# Subtree, depth = 0 (37224 data points).
# Split on feature term_ 36 months. (9223, 28001)
# --------------------------------------------------------------------
# Subtree, depth = 1 (9223 data points).
# Split on feature grade_A. (9122, 101)
# --------------------------------------------------------------------
# Subtree, depth = 2 (9122 data points).
# Split on feature grade_B. (8074, 1048)
# --------------------------------------------------------------------
# Subtree, depth = 3 (8074 data points).
# Split on feature grade_C. (5884, 2190)
# --------------------------------------------------------------------
# Subtree, depth = 4 (5884 data points).
# Split on feature grade_D. (3826, 2058)
# --------------------------------------------------------------------
# Subtree, depth = 5 (3826 data points).
# Split on feature grade_E. (1693, 2133)
# --------------------------------------------------------------------
# ...

# %%
model_3 = decision_tree_create(train_data, features_new, "safe_loans", current_depth = 0, max_depth = 14, min_node_size=0, min_error_reduction=-1)
# Out:
# --------------------------------------------------------------------
# Subtree, depth = 0 (37224 data points).
# Split on feature term_ 36 months. (9223, 28001)
# --------------------------------------------------------------------
# Subtree, depth = 1 (9223 data points).
# Split on feature grade_A. (9122, 101)
# --------------------------------------------------------------------
# Subtree, depth = 2 (9122 data points).
# Split on feature grade_B. (8074, 1048)
# --------------------------------------------------------------------
# Subtree, depth = 3 (8074 data points).
# Split on feature grade_C. (5884, 2190)
# --------------------------------------------------------------------
# Subtree, depth = 4 (5884 data points).
# Split on feature grade_D. (3826, 2058)
# --------------------------------------------------------------------
# Subtree, depth = 5 (3826 data points).
# Split on feature grade_E. (1693, 2133)
# --------------------------------------------------------------------
# ...

# %% [markdown]
# #### Now evaluate the classification error on the validation data.
# Quiz Question: Which tree has the smallest error on the validation data?
# ans: model_2
#
# Quiz Question: Does the tree with the smallest error in the training data also have the smallest error in the validation data?
# ans : No
#
# Quiz Question: Is it always true that the tree with the lowest classification error on the training set will result in the lowest classification error in the validation set
#
# Ans: False

# %%
evaluate_classification_error(model_1, validation_data)
# Out:
# 0.38140887548470487

# %%
evaluate_classification_error(model_2, validation_data)
# Out:
# 0.37774666092201636

# %%
evaluate_classification_error(model_3, validation_data)
# Out:
# 0.38140887548470487

# %%
evaluate_classification_error(model_2, train_data)
# Out:
# 0.3804266064904363

# %%
evaluate_classification_error(model_1, train_data)
# Out:
# 0.3772566086395874

# %%
evaluate_classification_error(model_3, train_data)
# Out:
# 0.3772566086395874

# %% [markdown]
# #### 26. Using the function count_leaves, compute the number of nodes in model_1, model_2, and model_3.
#
# Quiz question: Which tree has the largest complexity?
#
# ans: model_3
#
# Quiz question: Is it always true that the most complex tree will result in the lowest classification error in the validation_set?
# ans: false

# %%
def count_leaves(tree):
    if tree['is_leaf']:
        return 1
    return count_leaves(tree['left']) + count_leaves(tree['right'])

# %%
count_leaves(model_1)
# Out:
# 4

# %%
count_leaves(model_2)
# Out:
# 39

# %%
count_leaves(model_3)
# Out:
# 341

# %% [markdown]
# #### Exploring the effect of min_error
# We will compare three models trained with different values of the stopping criterion. We intentionally picked models at the extreme ends (negative, just right, and too positive).
#
# #### 27. Train three models with these parameters:
#
# model_4: min_error_reduction = -1 (ignoring this early stopping condition)
# model_5: min_error_reduction = 0 (just right)
# model_6: min_error_reduction = 5 (too positive)

# %%
model_4 = decision_tree_create(train_data, features_new, 'safe_loans', max_depth = 6, min_node_size = 0, min_error_reduction=-1)
# Out:
# --------------------------------------------------------------------
# Subtree, depth = 0 (37224 data points).
# Split on feature term_ 36 months. (9223, 28001)
# --------------------------------------------------------------------
# Subtree, depth = 1 (9223 data points).
# Split on feature grade_A. (9122, 101)
# --------------------------------------------------------------------
# Subtree, depth = 2 (9122 data points).
# Split on feature grade_B. (8074, 1048)
# --------------------------------------------------------------------
# Subtree, depth = 3 (8074 data points).
# Split on feature grade_C. (5884, 2190)
# --------------------------------------------------------------------
# Subtree, depth = 4 (5884 data points).
# Split on feature grade_D. (3826, 2058)
# --------------------------------------------------------------------
# Subtree, depth = 5 (3826 data points).
# Split on feature grade_E. (1693, 2133)
# --------------------------------------------------------------------
# ...

# %%
model_5 = decision_tree_create(train_data, features_new, 'safe_loans', max_depth = 6, min_node_size = 0, min_error_reduction=0)
# Out:
# --------------------------------------------------------------------
# Subtree, depth = 0 (37224 data points).
# Split on feature term_ 36 months. (9223, 28001)
# --------------------------------------------------------------------
# Subtree, depth = 1 (9223 data points).
# Split on feature grade_A. (9122, 101)
# --------------------------------------------------------------------
# Subtree, depth = 2 (9122 data points).
# Early stopping condition 3 reached. Minimum error reduction.
# --------------------------------------------------------------------
# Subtree, depth = 2 (101 data points).
# Split on feature emp_length_< 1 year. (90, 11)
# --------------------------------------------------------------------
# Subtree, depth = 3 (90 data points).
# Early stopping condition 3 reached. Minimum error reduction.
# --------------------------------------------------------------------
# Subtree, depth = 3 (11 data points).
# Early stopping condition 3 reached. Minimum error reduction.
# ...

# %%
model_6 = decision_tree_create(train_data, features_new, 'safe_loans', max_depth = 6, min_node_size = 0, min_error_reduction=-5)
# Out:
# --------------------------------------------------------------------
# Subtree, depth = 0 (37224 data points).
# Split on feature term_ 36 months. (9223, 28001)
# --------------------------------------------------------------------
# Subtree, depth = 1 (9223 data points).
# Split on feature grade_A. (9122, 101)
# --------------------------------------------------------------------
# Subtree, depth = 2 (9122 data points).
# Split on feature grade_B. (8074, 1048)
# --------------------------------------------------------------------
# Subtree, depth = 3 (8074 data points).
# Split on feature grade_C. (5884, 2190)
# --------------------------------------------------------------------
# Subtree, depth = 4 (5884 data points).
# Split on feature grade_D. (3826, 2058)
# --------------------------------------------------------------------
# Subtree, depth = 5 (3826 data points).
# Split on feature grade_E. (1693, 2133)
# --------------------------------------------------------------------
# ...

# %%
print ("Validation data, classification error (model 4):", evaluate_classification_error(model_4, validation_data))
print ("Validation data, classification error (model 5):", evaluate_classification_error(model_5, validation_data))
print ("Validation data, classification error (model 6):", evaluate_classification_error(model_6, validation_data))
# Out:
# Validation data, classification error (model 4): 0.37774666092201636
# Validation data, classification error (model 5): 0.37774666092201636
# Validation data, classification error (model 6): 0.37774666092201636
